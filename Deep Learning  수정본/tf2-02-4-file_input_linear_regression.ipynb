# %%
# !pip install tensorflow==2.0.0-beta1

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
xy = np.loadtxt('/content/gdrive/My Drive/tensorflow2-ipynb/data-01-test-score.csv', delimiter=',')
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

# %%
print("x_data", x_data)
print("y_data", y_data)
# Out:
# x_data [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 89.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]
#  [ 69.  74.  77.]
#  [ 47.  56.  60.]
#  [ 87.  79.  90.]
#  [ 79.  70.  88.]
#  [ 69.  70.  73.]
#  [ 70.  65.  74.]
#  [ 93.  95.  91.]
#  [ 79.  80.  73.]
#  [ 70.  73.  78.]
#  [ 93.  89.  96.]
#  [ 78.  75.  68.]
#  [ 81.  90.  93.]
#  [ 88.  92.  86.]
#  [ 78.  83.  77.]
#  [ 82.  86.  90.]
#  [ 86.  82.  89.]
#  [ 78.  83.  85.]
#  [ 76.  83.  71.]
#  [ 96.  93.  95.]]
# y_data [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]
#  [149.]
#  [115.]
#  [175.]
#  [164.]
#  [141.]
#  [141.]
#  [184.]
#  [152.]
#  [148.]
#  [192.]
#  [147.]
#  [183.]
#  [177.]
#  [159.]
#  [177.]
#  [175.]
#  [175.]
#  [149.]
#  [192.]]

# %%
epoch=1000

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(input_dim=3, units=1))

model.compile(loss='mse', optimizer='rmsprop')

# %%
history=model.fit(x_data, y_data, epochs=epoch)

# %%
epochs = np.arange(1, epoch+1)
plt.plot(epochs, history.history['loss'], label='Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
y_pred = model.predict(x_data)
print(y_data, y_pred)
plt.plot(y_data, 'o', label='target')
plt.plot(y_pred, 'x', label='prediction')

plt.legend(fontsize='x-large')
plt.show()
# Out:
# [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]
#  [149.]
#  [115.]
#  [175.]
#  [164.]
#  [141.]
#  [141.]
#  [184.]
#  [152.]
#  [148.]
#  [192.]
#  [147.]
#  [183.]
#  [177.]
#  [159.]
#  [177.]
#  [175.]
#  [175.]
#  [149.]
#  [192.]] [[152.87268]
#  [185.49054]
#  [181.82411]
#  [198.72408]
#  [141.28218]
#  [105.37468]
#  [149.24722]
#  [111.30155]
#  [174.57994]
#  [163.36307]
#  [143.59033]
#  [142.6008 ]
#  [187.18147]
#  [154.70355]
#  [150.26631]
#  [188.72891]
#  [147.02327]
#  [179.18481]
#  [178.06882]
#  [159.24911]
#  [175.04916]
#  [174.56516]
#  [166.54568]
#  [152.55836]
#  [191.65295]]
