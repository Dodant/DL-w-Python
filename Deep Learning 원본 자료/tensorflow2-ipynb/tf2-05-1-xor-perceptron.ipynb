# %%
# !pip install tensorflow==2.0.0-beta1
# Out:
# Collecting tensorflow==2.0.0-beta1
#   Downloading https://files.pythonhosted.org/packages/29/6c/2c9a5c4d095c63c2fb37d20def0e4f92685f7aee9243d6aae25862694fd1/tensorflow-2.0.0b1-cp36-cp36m-manylinux1_x86_64.whl (87.9MB)
#      |████████████████████████████████| 87.9MB 2.0MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (0.7.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (0.1.7)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (1.16.4)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (0.8.0)
# Collecting tb-nightly<1.14.0a20190604,>=1.14.0a20190603 (from tensorflow==2.0.0-beta1)
#   Downloading https://files.pythonhosted.org/packages/a4/96/571b875cd81dda9d5dfa1422a4f9d749e67c0a8d4f4f0b33a4e5f5f35e27/tb_nightly-1.14.0a20190603-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 39.3MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (1.0.8)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (3.7.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (1.11.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (1.12.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (1.15.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (0.2.2)
# Collecting tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 (from tensorflow==2.0.0-beta1)
#   Downloading https://files.pythonhosted.org/packages/32/dd/99c47dd007dcf10d63fd895611b063732646f23059c618a373e85019eb0e/tf_estimator_nightly-1.14.0.dev2019060501-py2.py3-none-any.whl (496kB)
#      |████████████████████████████████| 501kB 38.0MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-beta1) (0.33.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (0.15.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (41.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (3.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==2.0.0-beta1) (2.8.0)
# Installing collected packages: tb-nightly, tf-estimator-nightly, tensorflow
#   Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
# Successfully installed tb-nightly-1.14.0a20190603 tensorflow-2.0.0b1 tf-estimator-nightly-1.14.0.dev2019060501

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
x_data = np.array([[0., 0.],
          [0., 1.],
          [1., 0.],
          [1., 1.]])
y_data = np.array([[0.],
          [1.],
          [1.],
          [0.]])

plt.scatter(x_data[0, 0], x_data[0, 1],color='red', marker='o', label='0')
plt.scatter(x_data[3, 0], x_data[3, 1],color='red', marker='o', label='0')
plt.scatter(x_data[1, 0], x_data[1, 1],color='blue', marker='x', label='1')
plt.scatter(x_data[2, 0], x_data[2, 1],color='blue', marker='x', label='1')

plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='lower center')
plt.show()

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1, input_dim=2, activation='sigmoid'))

sgd = tf.keras.optimizers.SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer='rmsprop',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(x_data, y_data, epochs=100)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0723 10:36:46.040816 139811945797504 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 4 samples
# Epoch 1/100
# 4/4 [==============================] - 0s 20ms/sample - loss: 0.7735 - accuracy: 0.5000
# Epoch 2/100
# 4/4 [==============================] - 0s 891us/sample - loss: 0.7727 - accuracy: 0.5000
# Epoch 3/100
# 4/4 [==============================] - 0s 403us/sample - loss: 0.7721 - accuracy: 0.5000
# Epoch 4/100
# 4/4 [==============================] - 0s 545us/sample - loss: 0.7716 - accuracy: 0.5000
# Epoch 5/100
# 4/4 [==============================] - 0s 629us/sample - loss: 0.7712 - accuracy: 0.5000
# Epoch 6/100
# 4/4 [==============================] - 0s 365us/sample - loss: 0.7709 - accuracy: 0.5000
# Epoch 7/100
# 4/4 [==============================] - 0s 526us/sample - loss: 0.7705 - accuracy: 0.5000
# Epoch 8/100
# 4/4 [==============================] - 0s 776us/sample - loss: 0.7702 - accuracy: 0.5000
# Epoch 9/100
# 4/4 [==============================] - 0s 547us/sample - loss: 0.7699 - accuracy: 0.5000
# Epoch 10/100
# 4/4 [==============================] - 0s 612us/sample - loss: 0.7696 - accuracy: 0.5000
# Epoch 11/100
# 4/4 [==============================] - 0s 696us/sample - loss: 0.7693 - accuracy: 0.5000
# Epoch 12/100
# 4/4 [==============================] - 0s 573us/sample - loss: 0.7690 - accuracy: 0.5000
# Epoch 13/100
# 4/4 [==============================] - 0s 355us/sample - loss: 0.7687 - accuracy: 0.5000
# Epoch 14/100
# 4/4 [==============================] - 0s 506us/sample - loss: 0.7685 - accuracy: 0.5000
# Epoch 15/100
# 4/4 [==============================] - 0s 477us/sample - loss: 0.7682 - accuracy: 0.5000
# Epoch 16/100
# 4/4 [==============================] - 0s 673us/sample - loss: 0.7680 - accuracy: 0.5000
# Epoch 17/100
# 4/4 [==============================] - 0s 703us/sample - loss: 0.7677 - accuracy: 0.5000
# Epoch 18/100
# 4/4 [==============================] - 0s 798us/sample - loss: 0.7675 - accuracy: 0.5000
# Epoch 19/100
# 4/4 [==============================] - 0s 492us/sample - loss: 0.7672 - accuracy: 0.5000
# Epoch 20/100
# 4/4 [==============================] - 0s 373us/sample - loss: 0.7670 - accuracy: 0.5000
# Epoch 21/100
# 4/4 [==============================] - 0s 928us/sample - loss: 0.7668 - accuracy: 0.5000
# Epoch 22/100
# 4/4 [==============================] - 0s 499us/sample - loss: 0.7665 - accuracy: 0.5000
# Epoch 23/100
# 4/4 [==============================] - 0s 499us/sample - loss: 0.7663 - accuracy: 0.5000
# Epoch 24/100
# 4/4 [==============================] - 0s 471us/sample - loss: 0.7661 - accuracy: 0.5000
# Epoch 25/100
# 4/4 [==============================] - 0s 556us/sample - loss: 0.7659 - accuracy: 0.5000
# Epoch 26/100
# 4/4 [==============================] - 0s 763us/sample - loss: 0.7657 - accuracy: 0.5000
# Epoch 27/100
# 4/4 [==============================] - 0s 686us/sample - loss: 0.7654 - accuracy: 0.5000
# Epoch 28/100
# 4/4 [==============================] - 0s 594us/sample - loss: 0.7652 - accuracy: 0.5000
# Epoch 29/100
# 4/4 [==============================] - 0s 391us/sample - loss: 0.7650 - accuracy: 0.5000
# Epoch 30/100
# 4/4 [==============================] - 0s 387us/sample - loss: 0.7648 - accuracy: 0.5000
# Epoch 31/100
# 4/4 [==============================] - 0s 628us/sample - loss: 0.7646 - accuracy: 0.5000
# Epoch 32/100
# 4/4 [==============================] - 0s 482us/sample - loss: 0.7644 - accuracy: 0.5000
# Epoch 33/100
# 4/4 [==============================] - 0s 542us/sample - loss: 0.7641 - accuracy: 0.5000
# Epoch 34/100
# 4/4 [==============================] - 0s 526us/sample - loss: 0.7639 - accuracy: 0.5000
# Epoch 35/100
# 4/4 [==============================] - 0s 441us/sample - loss: 0.7637 - accuracy: 0.5000
# Epoch 36/100
# 4/4 [==============================] - 0s 916us/sample - loss: 0.7635 - accuracy: 0.5000
# Epoch 37/100
# 4/4 [==============================] - 0s 446us/sample - loss: 0.7633 - accuracy: 0.5000
# Epoch 38/100
# 4/4 [==============================] - 0s 630us/sample - loss: 0.7631 - accuracy: 0.5000
# Epoch 39/100
# 4/4 [==============================] - 0s 502us/sample - loss: 0.7629 - accuracy: 0.5000
# Epoch 40/100
# 4/4 [==============================] - 0s 517us/sample - loss: 0.7627 - accuracy: 0.5000
# Epoch 41/100
# 4/4 [==============================] - 0s 543us/sample - loss: 0.7625 - accuracy: 0.5000
# Epoch 42/100
# 4/4 [==============================] - 0s 501us/sample - loss: 0.7623 - accuracy: 0.5000
# Epoch 43/100
# 4/4 [==============================] - 0s 676us/sample - loss: 0.7621 - accuracy: 0.5000
# Epoch 44/100
# 4/4 [==============================] - 0s 549us/sample - loss: 0.7619 - accuracy: 0.5000
# Epoch 45/100
# 4/4 [==============================] - 0s 665us/sample - loss: 0.7617 - accuracy: 0.5000
# Epoch 46/100
# 4/4 [==============================] - 0s 699us/sample - loss: 0.7615 - accuracy: 0.5000
# Epoch 47/100
# 4/4 [==============================] - 0s 694us/sample - loss: 0.7613 - accuracy: 0.5000
# Epoch 48/100
# 4/4 [==============================] - 0s 629us/sample - loss: 0.7611 - accuracy: 0.5000
# Epoch 49/100
# 4/4 [==============================] - 0s 675us/sample - loss: 0.7609 - accuracy: 0.5000
# Epoch 50/100
# 4/4 [==============================] - 0s 554us/sample - loss: 0.7608 - accuracy: 0.5000
# Epoch 51/100
# 4/4 [==============================] - 0s 450us/sample - loss: 0.7606 - accuracy: 0.5000
# Epoch 52/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7604 - accuracy: 0.5000
# Epoch 53/100
# 4/4 [==============================] - 0s 792us/sample - loss: 0.7602 - accuracy: 0.5000
# Epoch 54/100
# 4/4 [==============================] - 0s 465us/sample - loss: 0.7600 - accuracy: 0.5000
# Epoch 55/100
# 4/4 [==============================] - 0s 389us/sample - loss: 0.7598 - accuracy: 0.5000
# Epoch 56/100
# 4/4 [==============================] - 0s 437us/sample - loss: 0.7596 - accuracy: 0.5000
# Epoch 57/100
# 4/4 [==============================] - 0s 441us/sample - loss: 0.7594 - accuracy: 0.5000
# Epoch 58/100
# 4/4 [==============================] - 0s 485us/sample - loss: 0.7593 - accuracy: 0.5000
# Epoch 59/100
# 4/4 [==============================] - 0s 499us/sample - loss: 0.7591 - accuracy: 0.5000
# Epoch 60/100
# 4/4 [==============================] - 0s 523us/sample - loss: 0.7589 - accuracy: 0.5000
# Epoch 61/100
# 4/4 [==============================] - 0s 401us/sample - loss: 0.7587 - accuracy: 0.5000
# Epoch 62/100
# 4/4 [==============================] - 0s 363us/sample - loss: 0.7585 - accuracy: 0.5000
# Epoch 63/100
# 4/4 [==============================] - 0s 421us/sample - loss: 0.7583 - accuracy: 0.5000
# Epoch 64/100
# 4/4 [==============================] - 0s 436us/sample - loss: 0.7582 - accuracy: 0.5000
# Epoch 65/100
# 4/4 [==============================] - 0s 364us/sample - loss: 0.7580 - accuracy: 0.5000
# Epoch 66/100
# 4/4 [==============================] - 0s 541us/sample - loss: 0.7578 - accuracy: 0.5000
# Epoch 67/100
# 4/4 [==============================] - 0s 404us/sample - loss: 0.7576 - accuracy: 0.5000
# Epoch 68/100
# 4/4 [==============================] - 0s 377us/sample - loss: 0.7575 - accuracy: 0.5000
# Epoch 69/100
# 4/4 [==============================] - 0s 392us/sample - loss: 0.7573 - accuracy: 0.5000
# Epoch 70/100
# 4/4 [==============================] - 0s 515us/sample - loss: 0.7571 - accuracy: 0.5000
# Epoch 71/100
# 4/4 [==============================] - 0s 431us/sample - loss: 0.7569 - accuracy: 0.5000
# Epoch 72/100
# 4/4 [==============================] - 0s 404us/sample - loss: 0.7568 - accuracy: 0.5000
# Epoch 73/100
# 4/4 [==============================] - 0s 551us/sample - loss: 0.7566 - accuracy: 0.5000
# Epoch 74/100
# 4/4 [==============================] - 0s 550us/sample - loss: 0.7564 - accuracy: 0.5000
# Epoch 75/100
# 4/4 [==============================] - 0s 583us/sample - loss: 0.7563 - accuracy: 0.5000
# Epoch 76/100
# 4/4 [==============================] - 0s 489us/sample - loss: 0.7561 - accuracy: 0.5000
# Epoch 77/100
# 4/4 [==============================] - 0s 363us/sample - loss: 0.7559 - accuracy: 0.5000
# Epoch 78/100
# 4/4 [==============================] - 0s 398us/sample - loss: 0.7558 - accuracy: 0.5000
# Epoch 79/100
# 4/4 [==============================] - 0s 510us/sample - loss: 0.7556 - accuracy: 0.5000
# Epoch 80/100
# 4/4 [==============================] - 0s 482us/sample - loss: 0.7554 - accuracy: 0.5000
# Epoch 81/100
# 4/4 [==============================] - 0s 506us/sample - loss: 0.7553 - accuracy: 0.5000
# Epoch 82/100
# 4/4 [==============================] - 0s 502us/sample - loss: 0.7551 - accuracy: 0.5000
# Epoch 83/100
# 4/4 [==============================] - 0s 623us/sample - loss: 0.7549 - accuracy: 0.5000
# Epoch 84/100
# 4/4 [==============================] - 0s 581us/sample - loss: 0.7548 - accuracy: 0.5000
# Epoch 85/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.7546 - accuracy: 0.5000
# Epoch 86/100
# 4/4 [==============================] - 0s 586us/sample - loss: 0.7545 - accuracy: 0.5000
# Epoch 87/100
# 4/4 [==============================] - 0s 422us/sample - loss: 0.7543 - accuracy: 0.5000
# Epoch 88/100
# 4/4 [==============================] - 0s 452us/sample - loss: 0.7541 - accuracy: 0.5000
# Epoch 89/100
# 4/4 [==============================] - 0s 698us/sample - loss: 0.7540 - accuracy: 0.5000
# Epoch 90/100
# 4/4 [==============================] - 0s 648us/sample - loss: 0.7538 - accuracy: 0.5000
# Epoch 91/100
# 4/4 [==============================] - 0s 470us/sample - loss: 0.7537 - accuracy: 0.5000
# Epoch 92/100
# 4/4 [==============================] - 0s 649us/sample - loss: 0.7535 - accuracy: 0.5000
# Epoch 93/100
# 4/4 [==============================] - 0s 470us/sample - loss: 0.7534 - accuracy: 0.5000
# Epoch 94/100
# 4/4 [==============================] - 0s 464us/sample - loss: 0.7532 - accuracy: 0.5000
# Epoch 95/100
# 4/4 [==============================] - 0s 505us/sample - loss: 0.7530 - accuracy: 0.5000
# Epoch 96/100
# 4/4 [==============================] - 0s 561us/sample - loss: 0.7529 - accuracy: 0.5000
# Epoch 97/100
# 4/4 [==============================] - 0s 492us/sample - loss: 0.7527 - accuracy: 0.5000
# Epoch 98/100
# 4/4 [==============================] - 0s 444us/sample - loss: 0.7526 - accuracy: 0.5000
# Epoch 99/100
# 4/4 [==============================] - 0s 478us/sample - loss: 0.7524 - accuracy: 0.5000
# Epoch 100/100
# 4/4 [==============================] - 0s 599us/sample - loss: 0.7523 - accuracy: 0.5000

# %%
score = model.evaluate(x_data, y_data, verbose=0)

# %%
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.7521379590034485
# Test accuracy: 0.5

# %%
history_dict = history.history
print(history_dict.keys())

acc = history.history['accuracy']
loss = history.history['loss']

epochs = range(1, len(acc) + 1)

# ‘bo’는 파란색 점을 의미합니다
plt.plot(epochs, loss, '-', label='Training loss')
plt.title('Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
plt.clf()   # 그래프를 초기화합니다
acc = history.history['accuracy']

plt.plot(epochs, acc, '-', label='Training acc')
plt.title('Training  accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
plt.scatter(x_data[0, 0], x_data[0, 1],color='red', marker='o', label='0')
plt.scatter(x_data[3, 0], x_data[3, 1],color='red', marker='o', label='0')
plt.scatter(x_data[1, 0], x_data[1, 1],color='blue', marker='x', label='1')
plt.scatter(x_data[2, 0], x_data[2, 1],color='blue', marker='x', label='1')

plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='lower right')

resolution=0.02
colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
cmap = ListedColormap(colors[:2])
x1_min, x1_max = x_data[:, 0].min() - 0.5, x_data[:, 0].max() + 0.5
x2_min, x2_max = x_data[:, 1].min() - 0.5, x_data[:, 1].max() + 0.5
xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
Z = model.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
Z = Z.reshape(xx1.shape)
plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
plt.xlim(xx1.min(), xx1.max())
plt.ylim(xx2.min(), xx2.max())

plt.show()
